# %% [markdown]
# ## imports

# %%
# !pip install holidays==0.14.2
# !pip install prophet==1.1
# Out:
# Requirement already satisfied: holidays==0.14.2 in /usr/local/lib/python3.10/dist-packages (0.14.2)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from holidays==0.14.2) (2.4.0)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.10/dist-packages (from holidays==0.14.2) (2.3.1)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays==0.14.2) (0.3.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays==0.14.2) (2.8.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.3.0->holidays==0.14.2) (0.5.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays==0.14.2) (1.16.0)
# Requirement already satisfied: prophet==1.1 in /usr/local/lib/python3.10/dist-packages (1.1)
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (3.0.11)
# Requirement already satisfied: cmdstanpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (1.24.4)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (1.5.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (3.7.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (2.4.0)
# Requirement already satisfied: holidays>=0.13 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (0.14.2)
# Requirement already satisfied: setuptools>=42 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (71.0.4)
# Requirement already satisfied: setuptools-git>=1.2 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (4.66.5)
# Requirement already satisfied: wheel>=0.37.0 in /usr/local/lib/python3.10/dist-packages (from prophet==1.1) (0.44.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.1->prophet==1.1) (0.5.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->prophet==1.1) (0.5.12)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.10/dist-packages (from holidays>=0.13->prophet==1.1) (2.3.1)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.10/dist-packages (from holidays>=0.13->prophet==1.1) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet==1.1) (4.1.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->prophet==1.1) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet==1.1) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->prophet==1.1) (1.16.0)

# %%
from prophet import Prophet

# %%
import pandas as pd

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## leitura dos dados

# %%
df = pd.read_csv('/content/ma_lga_12345.csv')
df
# Out:
#        saledate      MA   type  bedrooms
# 0    30/09/2007  441854  house         2
# 1    31/12/2007  441854  house         2
# 2    31/03/2008  441854  house         2
# 3    30/06/2008  441854  house         2
# 4    30/09/2008  451583  house         2
# ..          ...     ...    ...       ...
# 342  30/09/2018  603281   unit         3
# 343  31/12/2018  601167   unit         3
# 344  31/03/2019  605637   unit         3
# 345  30/06/2019  599339   unit         3
# 346  30/09/2019  597884   unit         3
#
# [347 rows x 4 columns]

# %%
df['saledate'] = pd.to_datetime(df['saledate'], format='%d/%m/%Y')
df
# Out:
#       saledate      MA   type  bedrooms
# 0   2007-09-30  441854  house         2
# 1   2007-12-31  441854  house         2
# 2   2008-03-31  441854  house         2
# 3   2008-06-30  441854  house         2
# 4   2008-09-30  451583  house         2
# ..         ...     ...    ...       ...
# 342 2018-09-30  603281   unit         3
# 343 2018-12-31  601167   unit         3
# 344 2019-03-31  605637   unit         3
# 345 2019-06-30  599339   unit         3
# 346 2019-09-30  597884   unit         3
#
# [347 rows x 4 columns]

# %%
df.type.unique()
# Out:
# array(['house', 'unit'], dtype=object)

# %%
df_encoded = pd.get_dummies(df, columns=['type'], drop_first=True)
df_encoded
# Out:
#       saledate      MA  bedrooms  type_unit
# 0   2007-09-30  441854         2          0
# 1   2007-12-31  441854         2          0
# 2   2008-03-31  441854         2          0
# 3   2008-06-30  441854         2          0
# 4   2008-09-30  451583         2          0
# ..         ...     ...       ...        ...
# 342 2018-09-30  603281         3          1
# 343 2018-12-31  601167         3          1
# 344 2019-03-31  605637         3          1
# 345 2019-06-30  599339         3          1
# 346 2019-09-30  597884         3          1
#
# [347 rows x 4 columns]

# %% [markdown]
# ## predição com prophet

# %%
df_prophet = df_encoded[['saledate', 'MA', 'bedrooms', 'type_unit']].rename(columns={'saledate': 'ds', 'MA': 'y'})
df_prophet
# Out:
#             ds       y  bedrooms  type_unit
# 0   2007-09-30  441854         2          0
# 1   2007-12-31  441854         2          0
# 2   2008-03-31  441854         2          0
# 3   2008-06-30  441854         2          0
# 4   2008-09-30  451583         2          0
# ..         ...     ...       ...        ...
# 342 2018-09-30  603281         3          1
# 343 2018-12-31  601167         3          1
# 344 2019-03-31  605637         3          1
# 345 2019-06-30  599339         3          1
# 346 2019-09-30  597884         3          1
#
# [347 rows x 4 columns]

# %%
model = Prophet()
model.add_regressor('bedrooms')
model.add_regressor('type_unit')

# %%
model.fit(df_prophet)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpcl5x_odw/6sumq8wg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpcl5x_odw/kzzs_zqg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75687', 'data', 'file=/tmp/tmpcl5x_odw/6sumq8wg.json', 'init=/tmp/tmpcl5x_odw/kzzs_zqg.json', 'output', 'file=/tmp/tmp2r0cnf2u/prophet_model-20241007141500.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:15:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:15:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future_dates = model.make_future_dataframe(periods=5, freq='M')
future_dates['bedrooms'] = df_encoded['bedrooms'].iloc[-1]
future_dates['type_unit'] = df_encoded['type_unit'].iloc[-1]

# %%
forecast = model.predict(future_dates)

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10))
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 46 2018-09-30  631424.355978  571746.772447  685641.326579
# 47 2018-12-31  637834.457534  578217.579769  697103.273168
# 48 2019-03-31  635980.003901  576930.881006  694654.005360
# 49 2019-06-30  639563.395575  579606.191218  699036.812451
# 50 2019-09-30  642965.889201  588776.465622  699109.750360
# 51 2019-10-31  588909.522694  526684.653657  649324.046695
# 52 2019-11-30  601743.839491  544976.257798  661283.778264
# 53 2019-12-31  651807.145881  591291.990957  707717.738956
# 54 2020-01-31  611197.226769  554107.445172  668458.185675
# 55 2020-02-29  624800.180606  568342.174973  683742.655505

# %% [markdown]
# ## predição com LSTM

# %%
features = ['MA', 'bedrooms', 'type_unit']
data = df_encoded[features].values

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# %%
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length, 1:])
        y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(y)

# %%
sequence_length = 5
X, y = create_sequences(data_scaled, sequence_length)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - loss: 0.1703 - val_loss: 0.0231
# Epoch 2/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0396 - val_loss: 0.0027
# Epoch 3/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0248 - val_loss: 0.0182
# Epoch 4/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0208 - val_loss: 0.0226
# Epoch 5/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0203 - val_loss: 0.0099
# Epoch 6/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0211 - val_loss: 0.0075
# Epoch 7/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0158 - val_loss: 0.0130
# Epoch 8/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0156 - val_loss: 0.0110
# Epoch 9/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0177 - val_loss: 0.0106
# Epoch 10/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0149 - val_loss: 0.0100
# Epoch 11/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 12/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0152 - val_loss: 0.0085
# Epoch 13/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0164 - val_loss: 0.0088
# Epoch 14/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0130 - val_loss: 0.0084
# Epoch 15/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0125 - val_loss: 0.0081
# Epoch 16/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0143 - val_loss: 0.0088
# Epoch 17/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0122 - val_loss: 0.0083
# Epoch 18/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0153 - val_loss: 0.0094
# Epoch 19/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0173 - val_loss: 0.0102
# Epoch 20/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0177 - val_loss: 0.0092

# %%
y_pred_scaled = model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step

# %%
y_pred_combined = np.concatenate((y_pred_scaled, X_test[:, -1, 0].reshape(-1, 1), X_test[:, -1, 1].reshape(-1, 1)), axis=1)
y_pred = scaler.inverse_transform(y_pred_combined)[:, 0]

y_test_combined = np.concatenate((y_test.reshape(-1, 1), X_test[:, -1, 0].reshape(-1, 1), X_test[:, -1, 1].reshape(-1, 1)), axis=1)
y_test_original = scaler.inverse_transform(y_test_combined)[:, 0]

for i in range(5):
    print(f"valor predito: {y_pred[i]:.2f}, valor verdadeiro: {y_test_original[i]:.2f}")
# Out:
# valor predito: 411546.01, valor verdadeiro: 429832.00
# valor predito: 411546.01, valor verdadeiro: 431567.00
# valor predito: 411546.01, valor verdadeiro: 432730.00
# valor predito: 411546.01, valor verdadeiro: 432791.00
# valor predito: 411546.01, valor verdadeiro: 432801.00
